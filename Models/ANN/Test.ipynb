# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
# Load the dataset from the CSV file
df = pd.read_csv('Dataset-1.csv')

# Ensure the dataset has at least 54 columns (52 features + 2 target features)
assert df.shape[1] >= 54, "The dataset must have at least 54 columns."

# Separate the features (first 52 columns) into X and the target (last 2 columns) into y
X = df.iloc[:, :52].values  # The first 52 columns
y = df.iloc[:, 52:54].values  # The last 2 columns

# Shuffle the dataset
np.random.seed(42)  # Ensure reproducibility
shuffled_indices = np.random.permutation(len(X))

# Determine the split index (e.g., 80% training, 20% testing)
split_index = int(len(X) * 0.8)

# Split into training and testing sets
train_indices = shuffled_indices[:split_index]
test_indices = shuffled_indices[split_index:]

X_train, X_test = X[train_indices], X[test_indices]
y_train, y_test = y[train_indices], y[test_indices]

# Verify the shapes of the splits
print(f"X_train shape: {X_train.shape}")  # Should be (80% of samples, 52)
print(f"X_test shape: {X_test.shape}")    # Should be (20% of samples, 52)
print(f"y_train shape: {y_train.shape}")  # Should be (80% of samples, 2)
print(f"y_test shape: {y_test.shape}")    # Should be (20% of samples, 2)
# Out:
# X_train shape: (7999, 52)
# X_test shape: (2000, 52)
# y_train shape: (7999, 2)
# y_test shape: (2000, 2)

# %%
# X = np.random.rand(1000, 52)  # Example X with 1000 samples and d features
# y = np.random.rand(1000, 52) 
# print(type(X),y)
# # X=np.array(X)
# # y=np.array(y)
# # print(type(X),type(y))

import numpy as np

# Check for NaNs or Infs in X and y
print("NaNs in X:", np.isnan(X).sum())
print("Infs in X:", np.isinf(X).sum())
print("NaNs in y:", np.isnan(y).sum())
print("Infs in y:", np.isinf(y).sum())

# Check the shape of X and y
print("X shape:", X.shape)
print("y shape:", y.shape)

# Check the data types of X and y
print("X dtype:", X.dtype)
print("y dtype:", y.dtype)
# Out:
# NaNs in X: 0
# Infs in X: 0
# NaNs in y: 0
# Infs in y: 0
# X shape: (9999, 52)
# y shape: (9999, 2)
# X dtype: float64
# y dtype: float64

# %%
X=np.array(X_train)
y=np.array(y_train)

# Define the ANN model

model = Sequential()

# Input layer
model.add(Dense(units=64, activation='relu', input_shape=(52,)))

# Hidden layer 1
model.add(Dense(units=128, activation='relu'))

# Hidden layer 2
model.add(Dense(units=64, activation='relu'))

# Output layer
model.add(Dense(units=2, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model and print the loss every 100th epoch
class PrintLossCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 100 == 0:
            print(f'Epoch {epoch + 1}, Loss: {logs["loss"]:.4f}')
            
print(type(X))

# Train the model
history=model.fit(X, y, epochs=100, batch_size=32, callbacks=[PrintLossCallback()])



# Plot the loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs. Epochs')
plt.grid(True)
plt.legend()
plt.show()

# Save the model architecture as an image file
# plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)
# Out:
# <class 'numpy.ndarray'>
# Epoch 1/100
# d:\GOPAL DATA\iit ropar\SUBJECTS\CS-542\Project\myenv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0261
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0134
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0095
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0032
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.0455e-04
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9319e-04
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3847e-04
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.3600e-04
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.3809e-04
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.2534e-04
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6049e-04
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.6210e-04
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0346e-04
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2205e-04
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0702e-04
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.0972e-04
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.3444e-04
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2135e-04
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.8835e-04
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.4945e-04
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2223e-04
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2794e-04
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8251e-04
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.6526e-04
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.7022e-04
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6995e-04
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8618e-04
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6374e-04
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3175e-04
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9954e-04
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0766e-04
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5779e-04
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5086e-04
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8251e-04
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6710e-04
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0141e-04
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5234e-04
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9935e-04
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6986e-04
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8517e-04
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0763e-04
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6825e-04
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.4212e-04
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.3023e-04
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8521e-04
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.9541e-04
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5261e-04
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9751e-04
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5500e-04
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8586e-04
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5133e-04
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1047e-04
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.4514e-04
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7242e-04
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0147e-04
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2168e-04
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6786e-04
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6736e-04
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8311e-04
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9954e-04
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3333e-04
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0368e-04
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2180e-04
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.7173e-04
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6319e-04
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5399e-04
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9753e-04
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6471e-04
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.1520e-04
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7339e-04
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.2764e-04
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9365e-04
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4874e-04
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8861e-04
# Epoch 77/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3544e-04
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3236e-04
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3675e-04
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1606e-04
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6529e-04
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8281e-04
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2093e-04
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4071e-04
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3609e-04
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7554e-04
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.0207e-04
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5463e-04
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8513e-04
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8689e-04
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3703e-04
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.0331e-04
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9557e-04
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7455e-04
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.4370e-04
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8117e-04
# Epoch 97/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8340e-04
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.7981e-04
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.9115e-04
# Epoch 100/100
# 236/250 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7897e-04Epoch 100, Loss: 0.0005
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8363e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         3,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,296 (235.54 KB)
#  Trainable params: 20,098 (78.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 40,198 (157.03 KB)

# %%
# Save the model architecture as an image file
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# Convert test data to numpy arrays if they are not already
X_test = np.array(X_test)
y_test = np.array(y_test)

# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the Mean Squared Error (MSE) manually
mse = np.mean((y_test - y_pred) ** 2)
print(f"Mean Squared Error on Test Set: {mse:.4f}")

# Compare a few predicted vs actual values
print("\nComparison of predicted and actual values (first 5 examples):")
for i in range(5):
    print(f"Actual: {y_test[i]}, Predicted: {y_pred[i]}")
# Out:
# Test Loss: 0.0001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error on Test Set: 0.0001
#
# Comparison of predicted and actual values (first 5 examples):
# Actual: [ 0.46202683 -0.37673469], Predicted: [ 0.46393698 -0.3754518 ]
# Actual: [0. 0.], Predicted: [0.00107243 0.00499096]
# Actual: [0.38309275 0.27148782], Predicted: [0.3483308  0.30285972]
# Actual: [0. 0.], Predicted: [0.00107243 0.00499096]
# Actual: [ 0.         -0.29662889], Predicted: [ 0.00434443 -0.2931    ]

# %%
from scipy.ndimage import gaussian_filter1d  # For smoothing the curve

# Step 1: Calculate the magnitude for both actual and predicted values
def calculate_magnitude(y):
    return np.sqrt(y[:, 0]**2 + y[:, 1]**2)

y_test_magnitude = calculate_magnitude(y_test)
y_pred_magnitude = calculate_magnitude(y_pred)

# Step 2: Define accuracy as Mean Squared Error (MSE)
def calculate_mse(actual, predicted):
    return (actual - predicted) ** 2

# Step 3: Create bins based on magnitude ranges
bins = np.linspace(min(y_test_magnitude), max(y_test_magnitude), 10)
bin_indices = np.digitize(y_test_magnitude, bins)

# Step 4: Calculate the MSE for each bin
mse_per_bin = []
magnitude_per_bin = []

for i in range(1, len(bins)):
    bin_mask = (bin_indices == i)
    
    # Get actual and predicted values in the current bin
    actual_bin = y_test_magnitude[bin_mask]
    predicted_bin = y_pred_magnitude[bin_mask]
    
    if len(actual_bin) > 0:
        mse = calculate_mse(actual_bin, predicted_bin).mean()
        mse_per_bin.append(mse)
        magnitude_per_bin.append(actual_bin.mean())

# Step 5: Smooth the MSE values using a Gaussian filter for smoothing
mse_per_bin_smooth = gaussian_filter1d(mse_per_bin, sigma=1)

# Step 6: Plot MSE vs Magnitude with smoothing
plt.figure(figsize=(10, 6))
plt.plot(magnitude_per_bin, mse_per_bin_smooth, marker='o', color='r', label='Mean Squared Error (smoothed)')
plt.xlabel('Magnitude of (y1, y2)')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs Magnitude of (y1, y2)')
plt.grid(True)
plt.legend()
plt.show()
